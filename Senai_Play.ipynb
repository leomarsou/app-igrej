# %% [markdown]
# <a href="https://colab.research.google.com/github/leomarsou/app-igrej/blob/master/Senai_Play.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AULA 04

# %%
import matplotlib.pyplot as plt
import numpy as np

dados = np.random.randint(1, 100, 10)
type(dados)

plt.plot(dados)
plt.xticks(range(2, 19, 4));
plt.grid(
    color='red',
    linestyle='--',
    linewidth=0.5, axis='x'
)

# %% [markdown]
# AULA 05

# %%
import matplotlib.pyplot as plt
import numpy as np

dados = np.random.randint(0, 70, 10)
dados

plt.plot(dados)
plt.hlines(35, 1, 8, colors= 'red', label= 'meta do mês' )
plt.hlines(70, 1, 8, colors= '#6fedae', label= 'maior meta do mês' )
legend = plt.legend(loc = 'upper right')
